# %%
import pandas as pd

# %%
df_1 = pd.read_csv(r"data\site_1_train_data.csv")
df_2 = pd.read_csv(r"data\site_2_train_data.csv")
df_3 = pd.read_csv(r"data\site_3_train_data.csv")
df_4 = pd.read_csv(r"data\site_4_train_data.csv")
df_5 = pd.read_csv(r"data\site_5_train_data.csv")
df_6 = pd.read_csv(r"data\site_6_train_data.csv")
df_7 = pd.read_csv(r"data\site_7_train_data.csv")

df_1["location"] = "Satyawati College"
df_2["location"] = "Indira Gandhi International Airport"
df_3["location"] = "Jawaharlal Nehru Stadium"
df_4["location"] = "Bawana Industrial Area"
df_5["location"] = "Okhla Phase III"
df_6["location"] = "Japanese Park Lake"
df_7["location"] = "Sonia Vihar"

df = pd.concat([df_1,df_2,df_3,df_4,df_5,df_6,df_6,df_7])
df.to_csv("data/Merged_Train_Data.csv")

# %%
df_1 = pd.read_csv(r"data\site_1_unseen_Input_data.csv")
df_2 = pd.read_csv(r"data\site_2_unseen_Input_data.csv")
df_3 = pd.read_csv(r"data\site_3_unseen_Input_data.csv")
df_4 = pd.read_csv(r"data\site_4_unseen_Input_data.csv")
df_5 = pd.read_csv(r"data\site_5_unseen_Input_data.csv")
df_6 = pd.read_csv(r"data\site_6_unseen_Input_data.csv")
df_7 = pd.read_csv(r"data\site_7_unseen_Input_data.csv")

df_1["location"] = "Satyawati College"
df_2["location"] = "Indira Gandhi International Airport"
df_3["location"] = "Jawaharlal Nehru Stadium"
df_4["location"] = "Bawana Industrial Area"
df_5["location"] = "Okhla Phase III"
df_6["location"] = "Japanese Park Lake"
df_7["location"] = "Sonia Vihar"

df = pd.concat([df_1,df_2,df_3,df_4,df_5,df_6,df_6,df_7])
df.to_csv("data/Merged_Test_Data.csv")
